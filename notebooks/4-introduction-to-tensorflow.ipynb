# %%
import tensorflow as tf

# placeholder for input
x = tf.placeholder(dtype=tf.float32)
# define the computational graph
y = tf.pow((2*x), 2) + (2*x) + 1

# initialize the variables
init_op = tf.global_variables_initializer()

# create a session
sess = tf.Session()

# %%
sess.run(init_op)

# run the computational graph with input 10 to x
value = sess.run(y, feed_dict={x: 10})

print(value)
# Out:
# 421.0

# %%
# create a random variable
weights = tf.Variable(tf.random_normal(shape=[10]))
sess.run(tf.global_variables_initializer())
sess.run(weights)
# Out:
# array([ 1.3648736 , -0.3177527 ,  0.81198156, -0.9678135 , -0.8835291 ,
#         0.93036056, -0.05404968, -2.7542002 , -1.3584417 ,  0.5577406 ],
#       dtype=float32)
