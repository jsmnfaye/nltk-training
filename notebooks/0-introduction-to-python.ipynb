# %%
print('what is your name?')
name = input()
print('You suck, ', name)

name = input('Tell me your name')
# Out:
# what is your name?
# faye
# You suck,  faye
# Tell me your namefaye

# %%
names = ['faye','allaine','claire','margaret']

'colleen' in names
# Out:
# False

# %%
'colleen' not in names
# Out:
# True

# %%
scientist = {'Name': 'Alan Turing', 'Field': 'Mathematics'}
scientist.keys()
# Out:
# dict_keys(['Name', 'Field'])

# %%
len(scientist.keys())
# Out:
# 2

# %%
scientist.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9495055a237f> in <module>()
# ----> 1 scientist.keys()[0]
#
# TypeError: 'dict_keys' object does not support indexing

# %%
scientist.values()
# Out:
# dict_values(['Alan Turing', 'Mathematics'])
