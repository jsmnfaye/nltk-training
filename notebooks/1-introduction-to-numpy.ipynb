# %%
import numpy as np
x = np.array([1,2,3,3,3,3])
x
# Out:
# array([1, 2, 3, 3, 3, 3])

# %%
len(x)
# Out:
# 6

# %%
x[-3]
# Out:
# 3

# %%
a = np.zeros((2,2))

# %%
a
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
b = np.ones((2,2))
b
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
c = a/b

# %%
c
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
c = np.random.randint(10, size=5)
c
# Out:
# array([9, 2, 4, 4, 2])

# %%
d = np.random.randint(22, size=5)
d
# Out:
# array([21,  6,  3,  7,  3])

# %%
d-c
# Out:
# array([12,  4, -1,  3,  1])

# %%
a = np.zeros((2,2))

# %%
b = np.ones((2,2))

# %%
a/b
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
b/a
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[inf, inf],
#        [inf, inf]])

# %%
a = np.random.random((2,2))
a
# Out:
# array([[0.41014225, 0.73447443],
#        [0.06990826, 0.03067305]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0f4d413a1ec3> in <module>()
# ----> 1 b = np.random.randit(10, (2,2))
#
# AttributeError: module 'numpy.random' has no attribute 'randit'

# %%
np.subtract(a,b)
# Out:
# array([[-0.58985775, -0.26552557],
#        [-0.93009174, -0.96932695]])

# %%
np.dot(a,b)
# Out:
# array([[1.14461668, 1.14461668],
#        [0.10058131, 0.10058131]])

# %%
for x in a:
  print(x)
# Out:
# [0.41014225 0.73447443]
# [0.06990826 0.03067305]

# %%
np.equal(a,b)
# Out:
# array([[False, False],
#        [False, False]])

# %%
a = np.array([[1,2],[3,4]])

print(np.sum(a))
print(np.sum(a, axis=0))
print(np.sum(a, axis=1))
# Out:
# 10
# [4 6]
# [3 7]

# %%
np.array
